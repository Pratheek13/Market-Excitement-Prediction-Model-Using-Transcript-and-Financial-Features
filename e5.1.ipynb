# %%
import os, re, glob, warnings
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

import torch
from transformers import AutoTokenizer, AutoModel

import yfinance as yf

from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    mean_absolute_error, mean_squared_error, r2_score,
    accuracy_score, f1_score, roc_auc_score, classification_report
)
from xgboost import XGBRegressor, XGBClassifier

# ── CONFIG ─────────────────────────────────────────────────────────────────
MAEC_ROOT      = 'C:\\applied time series\\ats sem project\\ats data\\MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction-master'   # 📂 Change this to your dataset path
OUTPUT_DIR     = 'C:\\applied time series\\ats sem project\\outputs'   # 📂 Change this to your desired output path
DEVICE         = 'cuda' if torch.cuda.is_available() else 'cpu'
TRAIN_END_YEAR = 2018   # time-based split
TEST_START_YEAR= 2019

os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f'Device: {DEVICE}')
print(f'MAEC root: {MAEC_ROOT}')
print('✅ Imports complete')
# Out:
# Device: cuda
# MAEC root: C:\applied time series\ats sem project\ats data\MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction-master
# ✅ Imports complete

# %%
import os

MAEC_ROOT = os.path.join(MAEC_ROOT, 'MAEC_Dataset')

# Verify
folders = [d for d in os.listdir(MAEC_ROOT) if os.path.isdir(os.path.join(MAEC_ROOT, d))]
print(f"✅ Fixed! Found {len(folders)} folders")
print(f"Sample: {folders[:5]}")
# Out:
# ✅ Fixed! Found 3443 folders
# Sample: ['20150225_LMAT', '20150226_ACIW', '20150226_ADSK', '20150226_AMWD', '20150226_ANSS']

# %%
# ── CELL 4 (FIXED) — Full Build ────────────────────────────────────────────

def parse_folder_name(folder_name):
    """
    Handles formats like:
      20150302_MU
      20150302_TG_NX
      2015-03-02_MU   (just in case)
    Returns (date as dd/mm/yyyy string, ticker)
    """
    # Normalize: remove dashes from date part if present
    folder_name = folder_name.strip()
    parts = folder_name.split('_')
    
    if len(parts) < 2:
        return None, None
    
    raw_date = parts[0].replace('-', '')  # handle 2015-03-02 or 20150302
    ticker   = parts[-1].upper()          # last segment = ticker
    
    # Validate date is 8 digits
    if not raw_date.isdigit() or len(raw_date) != 8:
        return None, None
    
    try:
        # raw_date is YYYYMMDD → parse and reformat to dd/mm/yyyy
        dt   = datetime.strptime(raw_date, '%Y%m%d')
        date = dt.strftime('%d/%m/%Y')
    except ValueError:
        return None, None
    
    return date, ticker


def read_transcript(folder_path):
    """
    Reads the first .txt file found in the folder.
    Tries common names first, then falls back to any .txt.
    """
    candidates = ['text.txt', 'transcript.txt', 'call.txt', 'body.txt', 'content.txt']
    for c in candidates:
        fp = os.path.join(folder_path, c)
        if os.path.exists(fp):
            with open(fp, 'r', encoding='utf-8', errors='ignore') as f:
                return f.read().strip()
    
    # Fallback: grab any .txt file
    txt_files = glob.glob(os.path.join(folder_path, '*.txt'))
    if txt_files:
        with open(txt_files[0], 'r', encoding='utf-8', errors='ignore') as f:
            return f.read().strip()
    
    return None


# ── Main loop ──────────────────────────────────────────────────────────────
records       = []
skipped_parse = []
skipped_txt   = []

folders = sorted([
    d for d in os.listdir(MAEC_ROOT)
    if os.path.isdir(os.path.join(MAEC_ROOT, d))
])

print(f"Found {len(folders)} folders. Parsing...")

for folder in tqdm(folders, desc='Parsing folders'):
    date, ticker = parse_folder_name(folder)
    
    if date is None:
        skipped_parse.append(folder)
        continue
    
    transcript = read_transcript(os.path.join(MAEC_ROOT, folder))
    
    if transcript is None or len(transcript) < 50:
        skipped_txt.append(folder)
        continue
    
    records.append({
        'folder'    : folder,
        'ticker'    : ticker,
        'date'      : date,
        'transcript': transcript
    })

# ── Report ─────────────────────────────────────────────────────────────────
print(f"\n✅ Parsed successfully : {len(records)}")
print(f"❌ Skipped (bad name)  : {len(skipped_parse)}  e.g. {skipped_parse[:3]}")
print(f"❌ Skipped (no .txt)   : {len(skipped_txt)}   e.g. {skipped_txt[:3]}")

if len(records) == 0:
    print("\n⚠️  records is EMPTY. Check the two skip lists above.")
    print("Most likely cause: .txt file has a different name inside the folder.")
    print("Run this to inspect one folder:")
    print(f"  print(os.listdir(os.path.join(MAEC_ROOT, folders[0])))")
else:
    df_raw = pd.DataFrame(records)
    # date is already dd/mm/yyyy string — convert to datetime
    df_raw['date'] = pd.to_datetime(df_raw['date'], format='%d/%m/%Y')
    df_raw.to_csv(f'{OUTPUT_DIR}/events_raw.csv', index=False)

    print(f'\n✅ events_raw.csv  →  {len(df_raw)} events')
    print(df_raw[['ticker', 'date', 'folder']].head(10))
    print(f"\nDate range : {df_raw['date'].min().date()} → {df_raw['date'].max().date()}")
    print(f"Unique tickers: {df_raw['ticker'].nunique()}")
# Out:
# Found 3443 folders. Parsing...
# Parsing folders: 100%|██████████| 3443/3443 [00:01<00:00, 1871.70it/s]
# ✅ Parsed successfully : 3419
# ❌ Skipped (bad name)  : 0  e.g. []
# ❌ Skipped (no .txt)   : 24   e.g. ['20150504_TXRH', '20150506_NSIT', '20150508_WELL']
#
# ✅ events_raw.csv  →  3419 events
#   ticker       date         folder
# 0   LMAT 2015-02-25  20150225_LMAT
# 1   ACIW 2015-02-26  20150226_ACIW
# 2   ADSK 2015-02-26  20150226_ADSK
# 3   AMWD 2015-02-26  20150226_AMWD
# 4   ANSS 2015-02-26  20150226_ANSS
# 5    CRI 2015-02-26   20150226_CRI
# 6   ECPG 2015-02-26  20150226_ECPG
# 7    GPS 2015-02-26   20150226_GPS
# 8   IRDM 2015-02-26  20150226_IRDM
# 9    JCP 2015-02-26   20150226_JCP
#
# Date range : 2015-02-25 → 2018-06-21
# Unique tickers: 1209

# %%
# ── Load raw events (skip if running from scratch) ─────────────────────────
if 'df_raw' not in dir():
    df_raw = pd.read_csv(f'{OUTPUT_DIR}/events_raw.csv', parse_dates=['date'])

# ── Helper functions ───────────────────────────────────────────────────────

def get_prices(ticker, date, window=10):
    """
    Download adjusted close + volume around event date.
    Returns DataFrame with columns: adj_close, volume.
    """
    start = (date - timedelta(days=window*3)).strftime('%Y-%m-%d')
    end   = (date + timedelta(days=window*3)).strftime('%Y-%m-%d')
    try:
        data = yf.download(ticker, start=start, end=end, progress=False, auto_adjust=True)
        if data.empty:
            return None
        data.index = pd.to_datetime(data.index)
        return data[['Close', 'Volume']].rename(columns={'Close':'adj_close','Volume':'volume'})
    except Exception:
        return None


def get_market(date, window=10):
    start = (date - timedelta(days=window*3)).strftime('%Y-%m-%d')
    end   = (date + timedelta(days=window*3)).strftime('%Y-%m-%d')
    try:
        data = yf.download('^GSPC', start=start, end=end, progress=False, auto_adjust=True)
        if data.empty:
            return None
        data.index = pd.to_datetime(data.index)
        return data[['Close']].rename(columns={'Close':'market_close'})
    except Exception:
        return None


def compute_car(ticker_prices, market_prices, event_date):
    features = {}

    # ── Flatten MultiIndex columns if yfinance returns them ───────────────
    def flatten_df(df):
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = [col[0] for col in df.columns]
        return df

    ticker_prices = flatten_df(ticker_prices.copy())
    market_prices = flatten_df(market_prices.copy())

    # ── Ensure index is plain DatetimeIndex (drop ticker level if present) ─
    ticker_prices.index = pd.to_datetime(ticker_prices.index.get_level_values(0))
    market_prices.index = pd.to_datetime(market_prices.index.get_level_values(0))

    # ── Remove duplicate dates (keep last) ────────────────────────────────
    ticker_prices = ticker_prices[~ticker_prices.index.duplicated(keep='last')]
    market_prices = market_prices[~market_prices.index.duplicated(keep='last')]

    # ── Merge on date ──────────────────────────────────────────────────────
    df = ticker_prices.join(market_prices, how='inner')
    if len(df) < 5:
        return None

    # Log returns
    df['r_stock']  = np.log(df['adj_close'] / df['adj_close'].shift(1))
    df['r_market'] = np.log(df['market_close'] / df['market_close'].shift(1))
    df = df.dropna()

    if len(df) < 5:
        return None

    # Find event date (or next available trading day)
    trading_days = df.index.sort_values()
    future_days  = trading_days[trading_days >= pd.Timestamp(event_date)]
    if len(future_days) == 0:
        return None
    t0  = future_days[0]
    idx = trading_days.get_loc(t0)  # guaranteed integer now (no duplicates)

    # Estimation window: [-35, -5] for beta
    est_start  = max(0, idx - 35)
    est_end    = max(0, idx - 5)
    est_window = df.iloc[est_start:est_end]

    if len(est_window) < 10:
        beta, alpha = 1.0, 0.0
    else:
        from sklearn.linear_model import LinearRegression as LR
        X  = est_window['r_market'].values.reshape(-1, 1)
        y  = est_window['r_stock'].values
        lr = LR().fit(X, y)
        beta  = float(lr.coef_[0])
        alpha = float(lr.intercept_)

    # Abnormal return at a given position
    def get_ar(day_idx):
        if day_idx < 0 or day_idx >= len(df):
            return np.nan
        r_s = float(df['r_stock'].iloc[day_idx])
        r_m = float(df['r_market'].iloc[day_idx])
        return r_s - (alpha + beta * r_m)

    ar0 = get_ar(idx)
    ar1 = get_ar(idx + 1)

    # Both must be valid scalars
    if np.isnan(ar0) or np.isnan(ar1):
        return None

    features['CAR'] = ar0 + ar1
    features['AR0'] = ar0
    features['AR1'] = ar1

    # Returns r[-5 .. +5]
    for offset in range(-5, 6):
        features[f'r_{offset:+d}'] = get_ar(idx + offset)

    # Pre-event volatility
    features['pre_volatility'] = float(est_window['r_stock'].std()) if len(est_window) > 2 else np.nan

    # Volume ratio
    pre_vol_window = df.iloc[max(0, idx - 5):idx]['volume']
    event_vol      = float(df['volume'].iloc[idx]) if idx < len(df) else np.nan
    avg_pre_vol    = float(pre_vol_window.mean()) if len(pre_vol_window) > 0 else np.nan
    features['volume_ratio'] = event_vol / avg_pre_vol if (avg_pre_vol and avg_pre_vol > 0) else np.nan

    # Market return on event day
    features['market_r0'] = float(df['r_market'].iloc[idx]) if idx < len(df) else np.nan

    # Momentum [-20, -2]
    mom_start = max(0, idx - 20)
    mom_end   = max(0, idx - 1)
    features['momentum_20d'] = float(df.iloc[mom_start:mom_end]['r_stock'].sum())

    return features


# ── Main loop ──────────────────────────────────────────────────────────────
# Cache market data per date to avoid repeated downloads
market_cache = {}

fin_rows = []
failed   = 0

for _, row in tqdm(df_raw.iterrows(), total=len(df_raw), desc='Computing CAR'):
    ticker     = row['ticker']
    event_date = row['date']
    date_key   = event_date.strftime('%Y-%m')

    # Ticker prices
    prices = get_prices(ticker, event_date)
    if prices is None:
        failed += 1
        continue

    # Market prices (cache by month)
    if date_key not in market_cache:
        market_cache[date_key] = get_market(event_date)
    market = market_cache[date_key]
    if market is None:
        failed += 1
        continue

    car_features = compute_car(prices, market, event_date)
    if car_features is None:
        failed += 1
        continue

    combined = {
        'folder'    : row['folder'],
        'ticker'    : ticker,
        'date'      : event_date,
        'transcript': row['transcript'],
        **car_features
    }
    fin_rows.append(combined)


df_finance = pd.DataFrame(fin_rows)
df_finance.to_csv(f'{OUTPUT_DIR}/events_with_finance.csv', index=False)

print(f'\n✅ events_with_finance.csv  →  {len(df_finance)} events  ({failed} failed/skipped)')
print(f"CAR stats:\n{df_finance['CAR'].describe()}")
print(f"\nColumns: {list(df_finance.columns)}")
# Out:
# Computing CAR:   0%|          | 4/3419 [00:01<19:36,  2.90it/s]HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ANSS"}}}
# $ANSS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ANSS']: possibly delisted; no timezone found
# Computing CAR:   0%|          | 7/3419 [00:03<25:09,  2.26it/s]$GPS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GPS']: possibly delisted; no timezone found
# Computing CAR:   0%|          | 9/3419 [00:04<27:42,  2.05it/s]$JCP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JCP']: possibly delisted; no timezone found
# Computing CAR:   0%|          | 13/3419 [00:06<20:50,  2.72it/s]$RDC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['RDC']: possibly delisted; no timezone found
# Computing CAR:   0%|          | 14/3419 [00:06<23:25,  2.42it/s]$SJI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SJI']: possibly delisted; no timezone found
# Computing CAR:   0%|          | 15/3419 [00:07<29:06,  1.95it/s]$BID: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BID']: possibly delisted; no timezone found
# Computing CAR:   0%|          | 16/3419 [00:08<30:06,  1.88it/s]$MDR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDR']: possibly delisted; no timezone found
# Computing CAR:   1%|          | 20/3419 [00:09<21:54,  2.59it/s]$AMED: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AMED']: possibly delisted; no timezone found
# Computing CAR:   1%|          | 22/3419 [00:10<20:23,  2.78it/s]$ESL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ESL']: possibly delisted; no timezone found
# Computing CAR:   1%|          | 23/3419 [00:11<25:07,  2.25it/s]$FL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FL']: possibly delisted; no timezone found
# Computing CAR:   1%|          | 25/3419 [00:11<24:22,  2.32it/s]$RAVN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['RAVN']: possibly delisted; no timezone found
# Computing CAR:   1%|          | 30/3419 [00:13<17:40,  3.20it/s]$DSW: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DSW']: possibly delisted; no timezone found
# Computing CAR:   2%|▏         | 57/3419 [00:26<1:12:33,  1.30s/it]$SBNY: possibly delisted; no price data found  (1d 2015-03-22 -> 2015-05-21) (Yahoo error = "Data doesn't exist for startDate = 1426996800, endDate = 1432180800")
#
# 1 Failed download:
# ['SBNY']: possibly delisted; no price data found  (1d 2015-03-22 -> 2015-05-21) (Yahoo error = "Data doesn't exist for startDate = 1426996800, endDate = 1432180800")
# Computing CAR:   2%|▏         | 73/3419 [00:32<17:32,  3.18it/s]  $TUP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TUP']: possibly delisted; no timezone found
# Computing CAR:   2%|▏         | 74/3419 [00:32<22:02,  2.53it/s]$XLNX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['XLNX']: possibly delisted; no timezone found
# Computing CAR:   2%|▏         | 81/3419 [00:35<16:15,  3.42it/s]$EFII: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EFII']: possibly delisted; no timezone found
# Computing CAR:   2%|▏         | 83/3419 [00:36<20:04,  2.77it/s]$GHL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GHL']: possibly delisted; no timezone found
# Computing CAR:   3%|▎         | 87/3419 [00:38<19:12,  2.89it/s]$JNPR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JNPR']: possibly delisted; no timezone found
# Computing CAR:   3%|▎         | 89/3419 [00:38<19:33,  2.84it/s]$MDP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDP']: possibly delisted; no timezone found
# Computing CAR:   3%|▎         | 99/3419 [00:42<16:24,  3.37it/s]$SRCL: possibly delisted; no price data found  (1d 2015-03-24 -> 2015-05-23)
#
# 1 Failed download:
# ['SRCL']: possibly delisted; no price data found  (1d 2015-03-24 -> 2015-05-23)
# Computing CAR:   3%|▎         | 111/3419 [00:46<19:05,  2.89it/s]$BGFV: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BGFV']: possibly delisted; no timezone found
# Computing CAR:   3%|▎         | 112/3419 [00:47<22:16,  2.47it/s]$CIR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CIR']: possibly delisted; no timezone found
# Computing CAR:   3%|▎         | 119/3419 [00:50<17:21,  3.17it/s]$IIVI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['IIVI']: possibly delisted; no timezone found
# Computing CAR:   4%|▎         | 120/3419 [00:50<22:36,  2.43it/s]$LOGM: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LOGM']: possibly delisted; no timezone found
# Computing CAR:   4%|▎         | 124/3419 [00:52<21:32,  2.55it/s]$NATI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NATI']: possibly delisted; no timezone found
# Computing CAR:   4%|▍         | 129/3419 [00:54<17:29,  3.14it/s]$WYND: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WYND']: possibly delisted; no timezone found
# Computing CAR:   4%|▍         | 130/3419 [00:55<24:20,  2.25it/s]$AMED: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AMED']: possibly delisted; no timezone found
# Computing CAR:   4%|▍         | 136/3419 [00:56<17:00,  3.22it/s]$HF: possibly delisted; no price data found  (1d 2015-03-30 -> 2015-05-29) (Yahoo error = "Data doesn't exist for startDate = 1427688000, endDate = 1432872000")
#
# 1 Failed download:
# ['HF']: possibly delisted; no price data found  (1d 2015-03-30 -> 2015-05-29) (Yahoo error = "Data doesn't exist for startDate = 1427688000, endDate = 1432872000")
# Computing CAR:   4%|▍         | 137/3419 [00:57<24:58,  2.19it/s]$LL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LL']: possibly delisted; no timezone found
# Computing CAR:   4%|▍         | 140/3419 [00:59<23:10,  2.36it/s]$PX: possibly delisted; no price data found  (1d 2015-03-30 -> 2015-05-29) (Yahoo error = "Data doesn't exist for startDate = 1427688000, endDate = 1432872000")
#
# 1 Failed download:
# ['PX']: possibly delisted; no price data found  (1d 2015-03-30 -> 2015-05-29) (Yahoo error = "Data doesn't exist for startDate = 1427688000, endDate = 1432872000")
# Computing CAR:   4%|▍         | 141/3419 [00:59<28:11,  1.94it/s]$ABC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ABC']: possibly delisted; no timezone found
# Computing CAR:   4%|▍         | 144/3419 [01:00<19:31,  2.79it/s]$CHSP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CHSP']: possibly delisted; no timezone found
# Computing CAR:   4%|▍         | 146/3419 [01:01<22:50,  2.39it/s]$CRR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CRR']: possibly delisted; no timezone found
# Computing CAR:   4%|▍         | 152/3419 [01:03<16:59,  3.21it/s]$LLL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LLL']: possibly delisted; no timezone found
# Computing CAR:   5%|▍         | 155/3419 [01:05<19:03,  2.85it/s]$NTRI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NTRI']: possibly delisted; no timezone found
# Computing CAR:   5%|▍         | 159/3419 [01:06<15:55,  3.41it/s]$PKI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PKI']: possibly delisted; no timezone found
# Computing CAR:   5%|▍         | 170/3419 [01:10<16:07,  3.36it/s]$CTB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CTB']: possibly delisted; no timezone found
# Computing CAR:   5%|▌         | 172/3419 [01:11<20:53,  2.59it/s]$GWR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GWR']: possibly delisted; no timezone found
# Computing CAR:   5%|▌         | 173/3419 [01:11<29:09,  1.86it/s]$LM: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LM']: possibly delisted; no timezone found
# Computing CAR:   5%|▌         | 181/3419 [01:14<15:23,  3.51it/s]$CHUY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CHUY']: possibly delisted; no timezone found
# Computing CAR:   5%|▌         | 183/3419 [01:15<21:30,  2.51it/s]$DO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DO']: possibly delisted; no timezone found
# Computing CAR:   5%|▌         | 186/3419 [01:16<20:26,  2.64it/s]$NUVA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NUVA']: possibly delisted; no timezone found
# Computing CAR:   5%|▌         | 187/3419 [01:17<27:15,  1.98it/s]$ABMD: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ABMD']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 189/3419 [01:18<23:44,  2.27it/s]$CRAY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CRAY']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 190/3419 [01:19<28:53,  1.86it/s]$CTL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CTL']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 196/3419 [01:20<16:07,  3.33it/s]$K: possibly delisted; no timezone found
#
# 1 Failed download:
# ['K']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 199/3419 [01:22<21:49,  2.46it/s]$MDC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDC']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 200/3419 [01:23<24:47,  2.16it/s]$MDCO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDCO']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 206/3419 [01:25<16:32,  3.24it/s]$CRZO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CRZO']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 208/3419 [01:25<17:27,  3.07it/s]$HFC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HFC']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 209/3419 [01:26<24:26,  2.19it/s]$HSC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HSC']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 212/3419 [01:27<20:36,  2.59it/s]$RDC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['RDC']: possibly delisted; no timezone found
# Computing CAR:   6%|▌         | 213/3419 [01:28<25:37,  2.08it/s]$SNH: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SNH']: possibly delisted; no timezone found
# Computing CAR:   6%|▋         | 215/3419 [01:29<21:45,  2.45it/s]$VSI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['VSI']: possibly delisted; no timezone found
# Computing CAR:   6%|▋         | 219/3419 [01:31<21:41,  2.46it/s]$CBB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CBB']: possibly delisted; no timezone found
# Computing CAR:   6%|▋         | 221/3419 [01:33<43:49,  1.22it/s]$CNSL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CNSL']: possibly delisted; no timezone found
# Computing CAR:   6%|▋         | 222/3419 [01:34<42:38,  1.25it/s]$CUTR: possibly delisted; no price data found  (1d 2015-04-07 -> 2015-06-06)
#
# 1 Failed download:
# ['CUTR']: possibly delisted; no price data found  (1d 2015-04-07 -> 2015-06-06)
# Computing CAR:   7%|▋         | 226/3419 [01:35<19:12,  2.77it/s]$JCOM: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JCOM']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 230/3419 [01:36<15:01,  3.54it/s]$SPPI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SPPI']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 233/3419 [01:37<17:43,  3.00it/s]$EBIX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EBIX']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 236/3419 [01:38<16:14,  3.27it/s]$BID: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BID']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 237/3419 [01:39<25:51,  2.05it/s]$ENDP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ENDP']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 242/3419 [01:41<18:31,  2.86it/s]$JCP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JCP']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 244/3419 [01:41<20:00,  2.64it/s]$JWN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JWN']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 249/3419 [01:43<16:08,  3.27it/s]$GPS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GPS']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 254/3419 [01:46<18:57,  2.78it/s]$CHS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CHS']: possibly delisted; no timezone found
# Computing CAR:   7%|▋         | 256/3419 [01:46<18:21,  2.87it/s]$BIG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BIG']: possibly delisted; no timezone found
# Computing CAR:   8%|▊         | 257/3419 [01:47<23:23,  2.25it/s]$ASNA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ASNA']: possibly delisted; no timezone found
# Computing CAR:   8%|▊         | 267/3419 [01:51<14:46,  3.56it/s]$SONC: possibly delisted; no price data found  (1d 2015-05-23 -> 2015-07-22)
#
# 1 Failed download:
# ['SONC']: possibly delisted; no price data found  (1d 2015-05-23 -> 2015-07-22)
# Computing CAR:   8%|▊         | 270/3419 [01:51<13:29,  3.89it/s]$MON: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MON']: possibly delisted; no timezone found
# Computing CAR:   8%|▊         | 271/3419 [01:52<22:28,  2.33it/s]$BKS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BKS']: possibly delisted; no timezone found
# Computing CAR:   9%|▊         | 291/3419 [01:58<16:00,  3.26it/s]$KSU: possibly delisted; no timezone found
#
# 1 Failed download:
# ['KSU']: possibly delisted; no timezone found
# Computing CAR:   9%|▊         | 292/3419 [01:59<22:00,  2.37it/s]$EFII: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EFII']: possibly delisted; no timezone found
# Computing CAR:   9%|▉         | 304/3419 [02:02<12:39,  4.10it/s]$SBNY: possibly delisted; no price data found  (1d 2015-06-21 -> 2015-08-20) (Yahoo error = "Data doesn't exist for startDate = 1434859200, endDate = 1440043200")
#
# 1 Failed download:
# ['SBNY']: possibly delisted; no price data found  (1d 2015-06-21 -> 2015-08-20) (Yahoo error = "Data doesn't exist for startDate = 1434859200, endDate = 1440043200")
# Computing CAR:   9%|▉         | 315/3419 [02:06<12:41,  4.08it/s]$TUP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TUP']: possibly delisted; no timezone found
# Computing CAR:   9%|▉         | 316/3419 [02:06<17:58,  2.88it/s]$ABC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ABC']: possibly delisted; no timezone found
# Computing CAR:  10%|▉         | 328/3419 [02:10<13:19,  3.86it/s]$IVC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['IVC']: possibly delisted; no timezone found
# Computing CAR:  10%|▉         | 329/3419 [02:11<16:58,  3.03it/s]$JNPR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JNPR']: possibly delisted; no timezone found
# Computing CAR:  10%|█         | 343/3419 [02:15<12:44,  4.02it/s]$FLIR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FLIR']: possibly delisted; no timezone found
# Computing CAR:  10%|█         | 350/3419 [02:17<11:48,  4.33it/s]$POL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['POL']: possibly delisted; no timezone found
# Computing CAR:  10%|█         | 355/3419 [02:19<14:52,  3.43it/s]$BGFV: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BGFV']: possibly delisted; no timezone found
# Computing CAR:  10%|█         | 357/3419 [02:19<16:04,  3.18it/s]$CTXS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CTXS']: possibly delisted; no timezone found
# Computing CAR:  11%|█         | 359/3419 [02:20<17:28,  2.92it/s]$HSII: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HSII']: possibly delisted; no timezone found
# Computing CAR:  11%|█         | 361/3419 [02:21<18:19,  2.78it/s]$NATI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NATI']: possibly delisted; no timezone found
# Computing CAR:  11%|█         | 371/3419 [02:24<13:35,  3.74it/s]$PX: possibly delisted; no price data found  (1d 2015-06-29 -> 2015-08-28) (Yahoo error = "Data doesn't exist for startDate = 1435550400, endDate = 1440734400")
#
# 1 Failed download:
# ['PX']: possibly delisted; no price data found  (1d 2015-06-29 -> 2015-08-28) (Yahoo error = "Data doesn't exist for startDate = 1435550400, endDate = 1440734400")
# Computing CAR:  11%|█         | 373/3419 [02:25<17:42,  2.87it/s]$TGI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TGI']: possibly delisted; no timezone found
# Computing CAR:  11%|█         | 376/3419 [02:26<16:33,  3.06it/s]$BCOR: possibly delisted; no price data found  (1d 2015-06-30 -> 2015-08-29) (Yahoo error = "Data doesn't exist for startDate = 1435636800, endDate = 1440820800")
#
# 1 Failed download:
# ['BCOR']: possibly delisted; no price data found  (1d 2015-06-30 -> 2015-08-29) (Yahoo error = "Data doesn't exist for startDate = 1435636800, endDate = 1440820800")
# Computing CAR:  11%|█         | 377/3419 [02:26<20:45,  2.44it/s]$CBB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CBB']: possibly delisted; no timezone found
# Computing CAR:  11%|█         | 383/3419 [02:28<13:24,  3.77it/s]$HF: possibly delisted; no price data found  (1d 2015-06-30 -> 2015-08-29) (Yahoo error = "Data doesn't exist for startDate = 1435636800, endDate = 1440820800")
#
# 1 Failed download:
# ['HF']: possibly delisted; no price data found  (1d 2015-06-30 -> 2015-08-29) (Yahoo error = "Data doesn't exist for startDate = 1435636800, endDate = 1440820800")
# Computing CAR:  11%|█▏        | 387/3419 [02:29<12:18,  4.11it/s]$INT: possibly delisted; no timezone found
#
# 1 Failed download:
# ['INT']: possibly delisted; no timezone found
# Computing CAR:  11%|█▏        | 392/3419 [02:31<13:15,  3.80it/s]$PRFT: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PRFT']: possibly delisted; no timezone found
# Computing CAR:  12%|█▏        | 396/3419 [02:32<15:07,  3.33it/s]$TPX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TPX']: possibly delisted; no timezone found
# Computing CAR:  12%|█▏        | 397/3419 [02:33<23:14,  2.17it/s]$VG: possibly delisted; no price data found  (1d 2015-06-30 -> 2015-08-29) (Yahoo error = "Data doesn't exist for startDate = 1435636800, endDate = 1440820800")
#
# 1 Failed download:
# ['VG']: possibly delisted; no price data found  (1d 2015-06-30 -> 2015-08-29) (Yahoo error = "Data doesn't exist for startDate = 1435636800, endDate = 1440820800")
# Computing CAR:  12%|█▏        | 413/3419 [02:40<17:11,  2.92it/s]$ALE: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ALE']: possibly delisted; no timezone found
# Computing CAR:  12%|█▏        | 416/3419 [02:41<20:32,  2.44it/s]$CHUY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CHUY']: possibly delisted; no timezone found
# Computing CAR:  12%|█▏        | 422/3419 [02:43<16:53,  2.96it/s]$ACXM: possibly delisted; no price data found  (1d 2015-07-06 -> 2015-09-04)
#
# 1 Failed download:
# ['ACXM']: possibly delisted; no price data found  (1d 2015-07-06 -> 2015-09-04)
# Computing CAR:  12%|█▏        | 423/3419 [02:44<18:36,  2.68it/s]$ANSS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ANSS']: possibly delisted; no timezone found
# Computing CAR:  12%|█▏        | 424/3419 [02:45<23:47,  2.10it/s]$CTL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CTL']: possibly delisted; no timezone found
# Computing CAR:  12%|█▏        | 426/3419 [02:46<23:03,  2.16it/s]$CUTR: possibly delisted; no price data found  (1d 2015-07-06 -> 2015-09-04)
#
# 1 Failed download:
# ['CUTR']: possibly delisted; no price data found  (1d 2015-07-06 -> 2015-09-04)
# Computing CAR:  12%|█▏        | 427/3419 [02:47<35:38,  1.40it/s]$ECHO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ECHO']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 428/3419 [02:48<37:45,  1.32it/s]$EE: possibly delisted; no price data found  (1d 2015-07-06 -> 2015-09-04) (Yahoo error = "Data doesn't exist for startDate = 1436155200, endDate = 1441339200")
#
# 1 Failed download:
# ['EE']: possibly delisted; no price data found  (1d 2015-07-06 -> 2015-09-04) (Yahoo error = "Data doesn't exist for startDate = 1436155200, endDate = 1441339200")
# Computing CAR:  13%|█▎        | 433/3419 [02:50<22:39,  2.20it/s]$WCG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WCG']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 434/3419 [02:51<27:10,  1.83it/s]$AGN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AGN']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 438/3419 [02:53<21:26,  2.32it/s]$CUB: possibly delisted; no price data found  (1d 2015-07-07 -> 2015-09-05) (Yahoo error = "Data doesn't exist for startDate = 1436241600, endDate = 1441425600")
#
# 1 Failed download:
# ['CUB']: possibly delisted; no price data found  (1d 2015-07-07 -> 2015-09-05) (Yahoo error = "Data doesn't exist for startDate = 1436241600, endDate = 1441425600")
# Computing CAR:  13%|█▎        | 440/3419 [02:54<22:43,  2.18it/s]$PGNX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PGNX']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 442/3419 [02:55<22:53,  2.17it/s]$SPPI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SPPI']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 443/3419 [02:56<27:38,  1.79it/s]$STMP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['STMP']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 445/3419 [02:57<27:53,  1.78it/s]$VIAB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['VIAB']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 446/3419 [02:58<30:58,  1.60it/s]$EBIX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EBIX']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 447/3419 [02:58<31:26,  1.58it/s]$SJI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SJI']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 454/3419 [03:01<18:43,  2.64it/s]$JWN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JWN']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 456/3419 [03:02<22:14,  2.22it/s]$JCP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JCP']: possibly delisted; no timezone found
# Computing CAR:  13%|█▎        | 461/3419 [03:04<19:21,  2.55it/s]$GPS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GPS']: possibly delisted; no timezone found
# Computing CAR:  14%|█▎        | 464/3419 [03:06<19:43,  2.50it/s]$FL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FL']: possibly delisted; no timezone found
# Computing CAR:  14%|█▎        | 467/3419 [03:07<21:32,  2.28it/s]$FRED: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FRED']: possibly delisted; no timezone found
# Computing CAR:  14%|█▍        | 471/3419 [03:09<21:06,  2.33it/s]$BIG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BIG']: possibly delisted; no timezone found
# Computing CAR:  14%|█▍        | 476/3419 [03:12<21:55,  2.24it/s]$BKS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BKS']: possibly delisted; no timezone found
# Computing CAR:  14%|█▍        | 478/3419 [03:13<22:22,  2.19it/s]$RHT: possibly delisted; no timezone found
#
# 1 Failed download:
# ['RHT']: possibly delisted; no timezone found
# Computing CAR:  14%|█▍        | 486/3419 [03:16<20:40,  2.36it/s]$CAMP: possibly delisted; no price data found  (1d 2015-09-01 -> 2015-10-31) (Yahoo error = "Data doesn't exist for startDate = 1441080000, endDate = 1446264000")
#
# 1 Failed download:
# ['CAMP']: possibly delisted; no price data found  (1d 2015-09-01 -> 2015-10-31) (Yahoo error = "Data doesn't exist for startDate = 1441080000, endDate = 1446264000")
# Computing CAR:  14%|█▍        | 493/3419 [03:19<18:02,  2.70it/s]$XLNX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['XLNX']: possibly delisted; no timezone found
# Computing CAR:  15%|█▍        | 506/3419 [03:24<15:22,  3.16it/s]$UTX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['UTX']: possibly delisted; no timezone found
# Computing CAR:  15%|█▍        | 510/3419 [03:26<18:15,  2.65it/s]$CA: possibly delisted; no price data found  (1d 2015-09-21 -> 2015-11-20) (Yahoo error = "Data doesn't exist for startDate = 1442808000, endDate = 1447995600")
#
# 1 Failed download:
# ['CA']: possibly delisted; no price data found  (1d 2015-09-21 -> 2015-11-20) (Yahoo error = "Data doesn't exist for startDate = 1442808000, endDate = 1447995600")
# Computing CAR:  15%|█▍        | 511/3419 [03:27<23:58,  2.02it/s]$ELY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ELY']: possibly delisted; no timezone found
# Computing CAR:  15%|█▌        | 522/3419 [03:31<16:51,  2.86it/s]$CY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CY']: possibly delisted; no timezone found
# Computing CAR:  15%|█▌        | 528/3419 [03:34<17:26,  2.76it/s]$IVC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['IVC']: possibly delisted; no timezone found
# Computing CAR:  16%|█▌        | 530/3419 [03:34<18:11,  2.65it/s]$LOGM: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LOGM']: possibly delisted; no timezone found
# Computing CAR:  16%|█▌        | 540/3419 [03:37<11:31,  4.16it/s]$QSII: possibly delisted; no price data found  (1d 2015-09-22 -> 2015-11-21)
#
# 1 Failed download:
# ['QSII']: possibly delisted; no price data found  (1d 2015-09-22 -> 2015-11-21)
# Computing CAR:  16%|█▌        | 544/3419 [03:38<11:45,  4.07it/s]$SKX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SKX']: possibly delisted; no timezone found
# Computing CAR:  16%|█▌        | 549/3419 [03:40<12:15,  3.90it/s]$UMPQ: possibly delisted; no timezone found
#
# 1 Failed download:
# ['UMPQ']: possibly delisted; no timezone found
# Computing CAR:  16%|█▌        | 553/3419 [03:41<14:58,  3.19it/s]$COG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['COG']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 565/3419 [03:45<11:18,  4.21it/s]$BGFV: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BGFV']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 566/3419 [03:45<16:28,  2.89it/s]$CLD: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CLD']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 568/3419 [03:46<19:08,  2.48it/s]$CRY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CRY']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 574/3419 [03:48<12:49,  3.69it/s]$HSII: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HSII']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 575/3419 [03:49<18:51,  2.51it/s]$IIVI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['IIVI']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 577/3419 [03:50<20:54,  2.27it/s]$MDC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDC']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 578/3419 [03:50<22:21,  2.12it/s]$MDSO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDSO']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 579/3419 [03:51<26:54,  1.76it/s]$NUVA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NUVA']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 585/3419 [03:53<14:26,  3.27it/s]$ULTI: possibly delisted; no price data found  (1d 2015-09-27 -> 2015-11-26) (Yahoo error = "Data doesn't exist for startDate = 1443326400, endDate = 1448514000")
#
# 1 Failed download:
# ['ULTI']: possibly delisted; no price data found  (1d 2015-09-27 -> 2015-11-26) (Yahoo error = "Data doesn't exist for startDate = 1443326400, endDate = 1448514000")
# Computing CAR:  17%|█▋        | 589/3419 [03:54<14:42,  3.21it/s]$APC: possibly delisted; no price data found  (1d 2015-09-28 -> 2015-11-27) (Yahoo error = "Data doesn't exist for startDate = 1443412800, endDate = 1448600400")
#
# 1 Failed download:
# ['APC']: possibly delisted; no price data found  (1d 2015-09-28 -> 2015-11-27) (Yahoo error = "Data doesn't exist for startDate = 1443412800, endDate = 1448600400")
# Computing CAR:  17%|█▋        | 594/3419 [03:56<14:00,  3.36it/s]$DSPG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DSPG']: possibly delisted; no timezone found
# Computing CAR:  17%|█▋        | 595/3419 [03:57<22:07,  2.13it/s]$ECHO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ECHO']: possibly delisted; no timezone found
# Computing CAR:  18%|█▊        | 599/3419 [03:58<16:45,  2.81it/s]$NTRI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NTRI']: possibly delisted; no timezone found
# Computing CAR:  18%|█▊        | 602/3419 [03:59<15:35,  3.01it/s]$VAR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['VAR']: possibly delisted; no timezone found
# Computing CAR:  18%|█▊        | 607/3419 [04:01<15:13,  3.08it/s]$ALXN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ALXN']: possibly delisted; no timezone found
# Computing CAR:  18%|█▊        | 610/3419 [04:03<17:44,  2.64it/s]$BCOR: possibly delisted; no price data found  (1d 2015-09-29 -> 2015-11-28) (Yahoo error = "Data doesn't exist for startDate = 1443499200, endDate = 1448686800")
#
# 1 Failed download:
# ['BCOR']: possibly delisted; no price data found  (1d 2015-09-29 -> 2015-11-28) (Yahoo error = "Data doesn't exist for startDate = 1443499200, endDate = 1448686800")
# Computing CAR:  18%|█▊        | 622/3419 [04:06<12:19,  3.78it/s]$LANC: possibly delisted; no price data found  (1d 2015-09-29 -> 2015-11-28)
#
# 1 Failed download:
# ['LANC']: possibly delisted; no price data found  (1d 2015-09-29 -> 2015-11-28)
# Computing CAR:  18%|█▊        | 624/3419 [04:06<10:56,  4.25it/s]$LLL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LLL']: possibly delisted; no timezone found
# Computing CAR:  18%|█▊        | 631/3419 [04:08<12:02,  3.86it/s]$PES: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PES']: possibly delisted; no timezone found
# Computing CAR:  18%|█▊        | 632/3419 [04:09<19:46,  2.35it/s]$PX: possibly delisted; no price data found  (1d 2015-09-29 -> 2015-11-28) (Yahoo error = "Data doesn't exist for startDate = 1443499200, endDate = 1448686800")
#
# 1 Failed download:
# ['PX']: possibly delisted; no price data found  (1d 2015-09-29 -> 2015-11-28) (Yahoo error = "Data doesn't exist for startDate = 1443499200, endDate = 1448686800")
# Computing CAR:  19%|█▊        | 636/3419 [04:11<18:08,  2.56it/s]$TPX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TPX']: possibly delisted; no timezone found
# Computing CAR:  19%|█▊        | 641/3419 [04:13<17:14,  2.69it/s]$BGG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BGG']: possibly delisted; no timezone found
# Computing CAR:  19%|█▉        | 645/3419 [04:15<17:54,  2.58it/s]$GWR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GWR']: possibly delisted; no timezone found
# Computing CAR:  19%|█▉        | 654/3419 [04:18<13:29,  3.41it/s]$UFS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['UFS']: possibly delisted; no timezone found
# Computing CAR:  19%|█▉        | 657/3419 [04:19<18:35,  2.48it/s]$EDR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EDR']: possibly delisted; no timezone found
# Computing CAR:  19%|█▉        | 660/3419 [04:21<17:52,  2.57it/s]$CHUY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CHUY']: possibly delisted; no timezone found
# Computing CAR:  19%|█▉        | 662/3419 [04:22<19:01,  2.42it/s]$DISCA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DISCA']: possibly delisted; no timezone found
# Computing CAR:  20%|█▉        | 667/3419 [04:23<15:01,  3.05it/s]$MDCO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDCO']: possibly delisted; no timezone found
# Computing CAR:  20%|█▉        | 676/3419 [04:27<15:08,  3.02it/s]$CTL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CTL']: possibly delisted; no timezone found
# Computing CAR:  20%|█▉        | 681/3419 [04:29<14:08,  3.23it/s]$SPPI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SPPI']: possibly delisted; no timezone found
# Computing CAR:  20%|█▉        | 682/3419 [04:30<26:54,  1.69it/s]$AAWW: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AAWW']: possibly delisted; no timezone found
# Computing CAR:  20%|██        | 689/3419 [04:33<16:47,  2.71it/s]$CNSL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CNSL']: possibly delisted; no timezone found
# Computing CAR:  20%|██        | 693/3419 [04:35<17:33,  2.59it/s]$ENDP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ENDP']: possibly delisted; no timezone found
# Computing CAR:  20%|██        | 695/3419 [04:36<17:06,  2.65it/s]$HRC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HRC']: possibly delisted; no timezone found
# Computing CAR:  21%|██        | 702/3419 [04:38<16:53,  2.68it/s]$PLT: possibly delisted; no price data found  (1d 2015-10-06 -> 2015-12-05) (Yahoo error = "Data doesn't exist for startDate = 1444104000, endDate = 1449291600")
#
# 1 Failed download:
# ['PLT']: possibly delisted; no price data found  (1d 2015-10-06 -> 2015-12-05) (Yahoo error = "Data doesn't exist for startDate = 1444104000, endDate = 1449291600")
# Computing CAR:  21%|██        | 703/3419 [04:39<20:17,  2.23it/s]$SJI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SJI']: possibly delisted; no timezone found
# Computing CAR:  21%|██        | 714/3419 [04:44<15:46,  2.86it/s]$CIR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CIR']: possibly delisted; no timezone found
# Computing CAR:  21%|██        | 715/3419 [04:44<21:54,  2.06it/s]$DISH: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DISH']: possibly delisted; no timezone found
# Computing CAR:  21%|██        | 717/3419 [04:46<28:35,  1.58it/s]$LABL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LABL']: possibly delisted; no timezone found
# Computing CAR:  21%|██        | 719/3419 [04:47<24:37,  1.83it/s]$MDR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDR']: possibly delisted; no timezone found
# Computing CAR:  21%|██        | 721/3419 [04:48<24:39,  1.82it/s]$SRDX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SRDX']: possibly delisted; no timezone found
# Computing CAR:  21%|██        | 723/3419 [04:49<22:22,  2.01it/s]$JWN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['JWN']: possibly delisted; no timezone found
# Computing CAR:  21%|██▏       | 728/3419 [04:51<16:12,  2.77it/s]$ESL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ESL']: possibly delisted; no timezone found
# Computing CAR:  21%|██▏       | 729/3419 [04:52<18:53,  2.37it/s]$GPS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GPS']: possibly delisted; no timezone found
# Computing CAR:  21%|██▏       | 730/3419 [04:53<24:50,  1.80it/s]$KIRK: possibly delisted; no timezone found
#
# 1 Failed download:
# ['KIRK']: possibly delisted; no timezone found
# Computing CAR:  21%|██▏       | 733/3419 [04:54<19:38,  2.28it/s]$FL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FL']: possibly delisted; no timezone found
# Computing CAR:  21%|██▏       | 734/3419 [04:55<22:31,  1.99it/s]$HIBB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HIBB']: possibly delisted; no timezone found
# Computing CAR:  22%|██▏       | 739/3419 [04:56<15:03,  2.96it/s]$DSW: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DSW']: possibly delisted; no timezone found
# Computing CAR:  22%|██▏       | 741/3419 [04:57<17:44,  2.51it/s]$TECD: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TECD']: possibly delisted; no timezone found
# Computing CAR:  22%|██▏       | 742/3419 [04:58<19:38,  2.27it/s]$TIF: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TIF']: possibly delisted; no timezone found
# Computing CAR:  22%|██▏       | 745/3419 [04:59<18:35,  2.40it/s]$EXPR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EXPR']: possibly delisted; no timezone found
# Computing CAR:  22%|██▏       | 750/3419 [05:01<13:15,  3.35it/s]$FRAN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FRAN']: possibly delisted; no timezone found
# Computing CAR:  22%|██▏       | 760/3419 [05:05<14:42,  3.01it/s]$SONC: possibly delisted; no price data found  (1d 2015-12-06 -> 2016-02-04)
#
# 1 Failed download:
# ['SONC']: possibly delisted; no price data found  (1d 2015-12-06 -> 2016-02-04)
# Computing CAR:  22%|██▏       | 762/3419 [05:05<13:47,  3.21it/s]$RECN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['RECN']: possibly delisted; no timezone found
# Computing CAR:  23%|██▎       | 780/3419 [05:11<16:45,  2.62it/s]$ETFC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ETFC']: possibly delisted; no timezone found
# Computing CAR:  23%|██▎       | 784/3419 [05:14<34:00,  1.29it/s]$SIVB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SIVB']: possibly delisted; no timezone found
# Computing CAR:  23%|██▎       | 789/3419 [05:16<17:31,  2.50it/s]$BID: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BID']: possibly delisted; no timezone found
# Computing CAR:  23%|██▎       | 791/3419 [05:18<20:19,  2.16it/s]$STI: possibly delisted; no price data found  (1d 2015-12-23 -> 2016-02-21) (Yahoo error = "Data doesn't exist for startDate = 1450846800, endDate = 1456030800")
#
# 1 Failed download:
# ['STI']: possibly delisted; no price data found  (1d 2015-12-23 -> 2016-02-21) (Yahoo error = "Data doesn't exist for startDate = 1450846800, endDate = 1456030800")
# Computing CAR:  23%|██▎       | 794/3419 [05:19<15:57,  2.74it/s]$AKS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AKS']: possibly delisted; no timezone found
# Computing CAR:  23%|██▎       | 799/3419 [05:20<14:08,  3.09it/s]$IIVI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['IIVI']: possibly delisted; no timezone found
# Computing CAR:  23%|██▎       | 800/3419 [05:21<16:34,  2.63it/s]$ISCA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ISCA']: possibly delisted; no timezone found
# Computing CAR:  24%|██▎       | 805/3419 [05:23<15:19,  2.84it/s]$TSS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TSS']: possibly delisted; no timezone found
# Computing CAR:  24%|██▎       | 809/3419 [05:24<12:54,  3.37it/s]$CTXS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CTXS']: possibly delisted; no timezone found
# Computing CAR:  24%|██▎       | 810/3419 [05:25<17:58,  2.42it/s]$DFS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DFS']: possibly delisted; no timezone found
# Computing CAR:  24%|██▎       | 811/3419 [05:26<21:24,  2.03it/s]$EFII: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EFII']: possibly delisted; no timezone found
# Computing CAR:  24%|██▍       | 815/3419 [05:28<17:23,  2.50it/s]$MDP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDP']: possibly delisted; no timezone found
# Computing CAR:  24%|██▍       | 821/3419 [05:30<13:24,  3.23it/s]$ADS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ADS']: possibly delisted; no timezone found
# Computing CAR:  24%|██▍       | 825/3419 [05:31<15:04,  2.87it/s]$CPSI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CPSI']: possibly delisted; no timezone found
# Computing CAR:  24%|██▍       | 833/3419 [05:34<12:39,  3.41it/s]$KEM: possibly delisted; no price data found  (1d 2015-12-29 -> 2016-02-27) (Yahoo error = "Data doesn't exist for startDate = 1451365200, endDate = 1456549200")
#
# 1 Failed download:
# ['KEM']: possibly delisted; no price data found  (1d 2015-12-29 -> 2016-02-27) (Yahoo error = "Data doesn't exist for startDate = 1451365200, endDate = 1456549200")
# Computing CAR:  24%|██▍       | 834/3419 [05:35<17:59,  2.40it/s]$LLL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LLL']: possibly delisted; no timezone found
# Computing CAR:  25%|██▍       | 841/3419 [05:38<15:37,  2.75it/s]$TGI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TGI']: possibly delisted; no timezone found
# Computing CAR:  25%|██▍       | 849/3419 [05:42<17:46,  2.41it/s]$HRC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HRC']: possibly delisted; no timezone found
# Computing CAR:  25%|██▍       | 852/3419 [05:43<21:22,  2.00it/s]$PLT: possibly delisted; no price data found  (1d 2016-01-02 -> 2016-03-02) (Yahoo error = "Data doesn't exist for startDate = 1451710800, endDate = 1456894800")
#
# 1 Failed download:
# ['PLT']: possibly delisted; no price data found  (1d 2016-01-02 -> 2016-03-02) (Yahoo error = "Data doesn't exist for startDate = 1451710800, endDate = 1456894800")
# Computing CAR:  25%|██▌       | 862/3419 [05:47<15:29,  2.75it/s]$ALXN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ALXN']: possibly delisted; no timezone found
# Computing CAR:  25%|██▌       | 867/3419 [05:50<17:21,  2.45it/s]$FBHS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FBHS']: possibly delisted; no timezone found
# Computing CAR:  25%|██▌       | 870/3419 [05:51<16:42,  2.54it/s]$MDC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDC']: possibly delisted; no timezone found
# Computing CAR:  26%|██▌       | 872/3419 [05:52<20:07,  2.11it/s]$POL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['POL']: possibly delisted; no timezone found
# Computing CAR:  26%|██▌       | 878/3419 [05:55<16:00,  2.64it/s]$ELY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ELY']: possibly delisted; no timezone found
# Computing CAR:  26%|██▌       | 887/3419 [05:58<14:09,  2.98it/s]$PJC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PJC']: possibly delisted; no timezone found
# Computing CAR:  26%|██▌       | 893/3419 [06:01<17:21,  2.43it/s]$TPX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TPX']: possibly delisted; no timezone found
# Computing CAR:  26%|██▌       | 897/3419 [06:03<16:35,  2.53it/s]$UFS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['UFS']: possibly delisted; no timezone found
# Computing CAR:  26%|██▋       | 899/3419 [06:04<19:44,  2.13it/s]$DO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DO']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 908/3419 [06:08<14:19,  2.92it/s]$GLT: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GLT']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 909/3419 [06:09<18:46,  2.23it/s]$LABL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LABL']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 915/3419 [06:11<17:16,  2.42it/s]$WCG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WCG']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 916/3419 [06:12<26:12,  1.59it/s]$WYND: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WYND']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 917/3419 [06:13<29:18,  1.42it/s]$CTL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CTL']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 919/3419 [06:14<26:12,  1.59it/s]$INTL: possibly delisted; no price data found  (1d 2016-01-11 -> 2016-03-11) (Yahoo error = "Data doesn't exist for startDate = 1452488400, endDate = 1457672400")
#
# 1 Failed download:
# ['INTL']: possibly delisted; no price data found  (1d 2016-01-11 -> 2016-03-11) (Yahoo error = "Data doesn't exist for startDate = 1452488400, endDate = 1457672400")
# Computing CAR:  27%|██▋       | 922/3419 [06:16<21:44,  1.91it/s]$MDSO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MDSO']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 925/3419 [06:17<19:51,  2.09it/s]$ATVI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ATVI']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 927/3419 [06:19<21:41,  1.92it/s]$CRAY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CRAY']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 930/3419 [06:20<19:42,  2.11it/s]$IVC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['IVC']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 931/3419 [06:21<22:13,  1.87it/s]$LOGM: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LOGM']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 935/3419 [06:23<18:08,  2.28it/s]$NUVA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NUVA']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 939/3419 [06:26<30:09,  1.37it/s]$TYPE: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TYPE']: possibly delisted; no timezone found
# Computing CAR:  27%|██▋       | 940/3419 [06:27<32:27,  1.27it/s]$VG: possibly delisted; no price data found  (1d 2016-01-12 -> 2016-03-12) (Yahoo error = "Data doesn't exist for startDate = 1452574800, endDate = 1457758800")
#
# 1 Failed download:
# ['VG']: possibly delisted; no price data found  (1d 2016-01-12 -> 2016-03-12) (Yahoo error = "Data doesn't exist for startDate = 1452574800, endDate = 1457758800")
# Computing CAR:  28%|██▊       | 942/3419 [06:28<27:16,  1.51it/s]$WWE: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WWE']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 944/3419 [06:29<24:06,  1.71it/s]$IPG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['IPG']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 948/3419 [06:31<19:11,  2.15it/s]$CLD: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CLD']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 952/3419 [06:33<18:09,  2.26it/s]$MANT: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MANT']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 954/3419 [06:35<24:24,  1.68it/s]$AAN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AAN']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 955/3419 [06:36<30:48,  1.33it/s]$CBB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CBB']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 957/3419 [06:37<25:16,  1.62it/s]$DISH: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DISH']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 965/3419 [06:40<13:04,  3.13it/s]$CIR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CIR']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 966/3419 [06:41<19:28,  2.10it/s]$COG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['COG']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 970/3419 [06:43<17:31,  2.33it/s]$AGN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AGN']: possibly delisted; no timezone found
# Computing CAR:  28%|██▊       | 971/3419 [06:44<25:00,  1.63it/s]$EDR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EDR']: possibly delisted; no timezone found
# Computing CAR:  29%|██▊       | 982/3419 [06:47<10:22,  3.92it/s]$CHK: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CHK']: possibly delisted; no timezone found
# Computing CAR:  29%|██▉       | 987/3419 [06:49<12:52,  3.15it/s]$EV: possibly delisted; no price data found  (1d 2016-01-25 -> 2016-03-25) (Yahoo error = "Data doesn't exist for startDate = 1453698000, endDate = 1458878400")
#
# 1 Failed download:
# ['EV']: possibly delisted; no price data found  (1d 2016-01-25 -> 2016-03-25) (Yahoo error = "Data doesn't exist for startDate = 1453698000, endDate = 1458878400")
# Computing CAR:  29%|██▉       | 988/3419 [06:50<19:51,  2.04it/s]$FARO: possibly delisted; no timezone found
#
# 1 Failed download:
# ...
# ['CHK']: possibly delisted; no timezone found
# Computing CAR:  93%|█████████▎| 3190/3419 [24:09<01:30,  2.54it/s]$SPTN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SPTN']: possibly delisted; no timezone found
# Computing CAR:  93%|█████████▎| 3191/3419 [24:09<01:58,  1.92it/s]$SWM: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SWM']: possibly delisted; no timezone found
# Computing CAR:  93%|█████████▎| 3196/3419 [24:12<01:35,  2.34it/s]$FRGI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FRGI']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▎| 3199/3419 [24:13<01:30,  2.42it/s]$AAXN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AAXN']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▎| 3202/3419 [24:15<01:39,  2.17it/s]$BGFV: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BGFV']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▎| 3203/3419 [24:15<01:54,  1.88it/s]$CLGX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CLGX']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▎| 3204/3419 [24:16<02:12,  1.63it/s]$EE: possibly delisted; no price data found  (1d 2018-01-28 -> 2018-03-29) (Yahoo error = "Data doesn't exist for startDate = 1517115600, endDate = 1522296000")
#
# 1 Failed download:
# ['EE']: possibly delisted; no price data found  (1d 2018-01-28 -> 2018-03-29) (Yahoo error = "Data doesn't exist for startDate = 1517115600, endDate = 1522296000")
# Computing CAR:  94%|█████████▎| 3205/3419 [24:17<02:15,  1.58it/s]$EXTN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EXTN']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▍| 3207/3419 [24:18<02:18,  1.53it/s]$VSI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['VSI']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▍| 3209/3419 [24:20<02:09,  1.62it/s]$HSKA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HSKA']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▍| 3215/3419 [24:23<01:35,  2.13it/s]$TPRE: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TPRE']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▍| 3221/3419 [24:25<01:12,  2.73it/s]$SPPI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SPPI']: possibly delisted; no timezone found
# Computing CAR:  94%|█████████▍| 3223/3419 [24:27<01:41,  1.94it/s]$MCF: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MCF']: possibly delisted; no timezone found
# Computing CAR:  95%|█████████▍| 3231/3419 [24:30<01:19,  2.37it/s]$BPFH: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BPFH']: possibly delisted; no timezone found
# Computing CAR:  95%|█████████▍| 3233/3419 [24:32<01:59,  1.56it/s]$PBCT: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PBCT']: possibly delisted; no timezone found
# Computing CAR:  95%|█████████▍| 3244/3419 [24:37<01:08,  2.56it/s]$FMBI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FMBI']: possibly delisted; no timezone found
# Computing CAR:  95%|█████████▌| 3250/3419 [24:39<01:00,  2.80it/s]$PSB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PSB']: possibly delisted; no timezone found
# Computing CAR:  95%|█████████▌| 3252/3419 [24:40<01:19,  2.09it/s]$UCBI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['UCBI']: possibly delisted; no timezone found
# Computing CAR:  95%|█████████▌| 3258/3419 [24:43<01:09,  2.31it/s]$CCMP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CCMP']: possibly delisted; no timezone found
# Computing CAR:  95%|█████████▌| 3259/3419 [24:44<01:27,  1.84it/s]$CLD: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CLD']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3267/3419 [24:47<01:01,  2.46it/s]$GWB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GWB']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3268/3419 [24:48<01:21,  1.85it/s]$LANC: possibly delisted; no price data found  (1d 2018-03-27 -> 2018-05-26)
#
# 1 Failed download:
# ['LANC']: possibly delisted; no price data found  (1d 2018-03-27 -> 2018-05-26)
# Computing CAR:  96%|█████████▌| 3272/3419 [24:50<01:08,  2.15it/s]$NATI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NATI']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3274/3419 [24:51<01:11,  2.02it/s]$PX: possibly delisted; no price data found  (1d 2018-03-27 -> 2018-05-26) (Yahoo error = "Data doesn't exist for startDate = 1522123200, endDate = 1527307200")
#
# 1 Failed download:
# ['PX']: possibly delisted; no price data found  (1d 2018-03-27 -> 2018-05-26) (Yahoo error = "Data doesn't exist for startDate = 1522123200, endDate = 1527307200")
# Computing CAR:  96%|█████████▌| 3275/3419 [24:52<01:28,  1.63it/s]$ROIC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ROIC']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3278/3419 [24:54<01:14,  1.89it/s]$VVI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['VVI']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3281/3419 [24:55<01:02,  2.20it/s]$NR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NR']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3283/3419 [24:56<01:05,  2.06it/s]$PJC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PJC']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3285/3419 [24:57<00:56,  2.35it/s]$TMST: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TMST']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3287/3419 [24:58<01:00,  2.19it/s]$CTB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CTB']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▌| 3289/3419 [24:59<00:53,  2.43it/s]$DSPG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DSPG']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▋| 3293/3419 [25:00<00:44,  2.80it/s]$BGFV: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BGFV']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▋| 3295/3419 [25:01<00:55,  2.25it/s]$GWR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GWR']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▋| 3298/3419 [25:03<00:46,  2.60it/s]$PPBI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PPBI']: possibly delisted; no timezone found
# Computing CAR:  96%|█████████▋| 3299/3419 [25:03<00:53,  2.22it/s]$PRFT: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PRFT']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3302/3419 [25:05<00:54,  2.13it/s]$UFS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['UFS']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3303/3419 [25:05<01:00,  1.91it/s]$ACOR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ACOR']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3304/3419 [25:06<01:07,  1.70it/s]$ALE: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ALE']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3307/3419 [25:07<00:49,  2.27it/s]$CHK: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CHK']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3309/3419 [25:08<00:46,  2.37it/s]$CUB: possibly delisted; no price data found  (1d 2018-04-02 -> 2018-06-01) (Yahoo error = "Data doesn't exist for startDate = 1522641600, endDate = 1527825600")
#
# 1 Failed download:
# ['CUB']: possibly delisted; no price data found  (1d 2018-04-02 -> 2018-06-01) (Yahoo error = "Data doesn't exist for startDate = 1522641600, endDate = 1527825600")
# Computing CAR:  97%|█████████▋| 3311/3419 [25:09<00:43,  2.50it/s]$HFC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HFC']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3312/3419 [25:10<01:01,  1.74it/s]$ITG: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ITG']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3319/3419 [25:13<00:32,  3.06it/s]$PEI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PEI']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3320/3419 [25:13<00:44,  2.24it/s]$PES: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PES']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3324/3419 [25:15<00:32,  2.94it/s]$WIRE: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WIRE']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3326/3419 [25:16<00:36,  2.56it/s]$ABMD: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ABMD']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3327/3419 [25:16<00:45,  2.00it/s]$AEGN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['AEGN']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3329/3419 [25:17<00:42,  2.12it/s]$AHL: possibly delisted; no price data found  (1d 2018-04-03 -> 2018-06-02) (Yahoo error = "Data doesn't exist for startDate = 1522728000, endDate = 1527912000")
#
# 1 Failed download:
# ['AHL']: possibly delisted; no price data found  (1d 2018-04-03 -> 2018-06-02) (Yahoo error = "Data doesn't exist for startDate = 1522728000, endDate = 1527912000")
# Computing CAR:  97%|█████████▋| 3331/3419 [25:19<00:49,  1.77it/s]$CDR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CDR']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3332/3419 [25:20<00:52,  1.65it/s]$CLI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CLI']: possibly delisted; no timezone found
# Computing CAR:  97%|█████████▋| 3333/3419 [25:20<00:50,  1.71it/s]$CNSL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CNSL']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3334/3419 [25:21<00:57,  1.47it/s]$CPE: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CPE']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3337/3419 [25:22<00:38,  2.16it/s]$EXTN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['EXTN']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3342/3419 [25:24<00:26,  2.89it/s]$MRO: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MRO']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3345/3419 [25:25<00:27,  2.67it/s]$SWM: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SWM']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3346/3419 [25:26<00:34,  2.09it/s]$UNT: possibly delisted; no timezone found
#
# 1 Failed download:
# ['UNT']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3351/3419 [25:28<00:23,  2.91it/s]$FRED: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FRED']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3353/3419 [25:29<00:26,  2.51it/s]$HMSY: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HMSY']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3354/3419 [25:29<00:28,  2.28it/s]$HSKA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['HSKA']: possibly delisted; no timezone found
# Computing CAR:  98%|█████████▊| 3360/3419 [25:32<00:20,  2.82it/s]$NLS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NLS']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▊| 3369/3419 [25:35<00:13,  3.60it/s]$DF: possibly delisted; no timezone found
#
# 1 Failed download:
# ['DF']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▊| 3376/3419 [25:37<00:12,  3.55it/s]$MNTA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MNTA']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▉| 3381/3419 [25:38<00:10,  3.64it/s]$VRTV: possibly delisted; no timezone found
#
# 1 Failed download:
# ['VRTV']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▉| 3382/3419 [25:39<00:14,  2.60it/s]$WLH: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WLH']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▉| 3383/3419 [25:40<00:16,  2.14it/s]$CBB: possibly delisted; no timezone found
#
# 1 Failed download:
# ['CBB']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▉| 3387/3419 [25:41<00:10,  2.96it/s]$INTL: possibly delisted; no price data found  (1d 2018-04-09 -> 2018-06-08) (Yahoo error = "Data doesn't exist for startDate = 1523246400, endDate = 1528430400")
#
# 1 Failed download:
# ['INTL']: possibly delisted; no price data found  (1d 2018-04-09 -> 2018-06-08) (Yahoo error = "Data doesn't exist for startDate = 1523246400, endDate = 1528430400")
# Computing CAR:  99%|█████████▉| 3388/3419 [25:42<00:12,  2.45it/s]$ODP: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ODP']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▉| 3394/3419 [25:44<00:08,  3.08it/s]$VSI: possibly delisted; no timezone found
#
# 1 Failed download:
# ['VSI']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▉| 3395/3419 [25:44<00:09,  2.48it/s]$WTR: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WTR']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▉| 3400/3419 [25:46<00:05,  3.30it/s]$MHLD: possibly delisted; no timezone found
#
# 1 Failed download:
# ['MHLD']: possibly delisted; no timezone found
# Computing CAR:  99%|█████████▉| 3401/3419 [25:47<00:07,  2.48it/s]$PRSC: possibly delisted; no timezone found
#
# 1 Failed download:
# ['PRSC']: possibly delisted; no timezone found
# Computing CAR: 100%|█████████▉| 3402/3419 [25:48<00:09,  1.74it/s]$TPRE: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TPRE']: possibly delisted; no timezone found
# Computing CAR: 100%|█████████▉| 3405/3419 [25:49<00:06,  2.27it/s]$KEM: possibly delisted; no price data found  (1d 2018-04-17 -> 2018-06-16) (Yahoo error = "Data doesn't exist for startDate = 1523937600, endDate = 1529121600")
#
# 1 Failed download:
# ['KEM']: possibly delisted; no price data found  (1d 2018-04-17 -> 2018-06-16) (Yahoo error = "Data doesn't exist for startDate = 1523937600, endDate = 1529121600")
# Computing CAR: 100%|█████████▉| 3406/3419 [25:50<00:07,  1.80it/s]$RAVN: possibly delisted; no timezone found
#
# 1 Failed download:
# ['RAVN']: possibly delisted; no timezone found
# Computing CAR: 100%|█████████▉| 3407/3419 [25:50<00:07,  1.70it/s]$BRS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BRS']: possibly delisted; no timezone found
# Computing CAR: 100%|█████████▉| 3409/3419 [25:52<00:05,  1.81it/s]$LABL: possibly delisted; no timezone found
#
# 1 Failed download:
# ['LABL']: possibly delisted; no timezone found
# Computing CAR: 100%|█████████▉| 3415/3419 [25:54<00:01,  2.92it/s]$KIRK: possibly delisted; no timezone found
#
# 1 Failed download:
# ['KIRK']: possibly delisted; no timezone found
# Computing CAR: 100%|█████████▉| 3417/3419 [25:56<00:01,  1.59it/s]$FRED: possibly delisted; no timezone found
#
# 1 Failed download:
# ['FRED']: possibly delisted; no timezone found
# Computing CAR: 100%|█████████▉| 3418/3419 [25:56<00:00,  1.44it/s]$BKS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BKS']: possibly delisted; no timezone found
# Computing CAR: 100%|██████████| 3419/3419 [25:57<00:00,  2.19it/s]
# ✅ events_with_finance.csv  →  2509 events  (910 failed/skipped)
# CAR stats:
# count    2509.000000
# mean        0.001262
# std         0.075080
# min        -0.746725
# 25%        -0.035477
# 50%         0.002678
# 75%         0.038017
# max         0.460675
# Name: CAR, dtype: float64
#
# Columns: ['folder', 'ticker', 'date', 'transcript', 'CAR', 'AR0', 'AR1', 'r_-5', 'r_-4', 'r_-3', 'r_-2', 'r_-1', 'r_+0', 'r_+1', 'r_+2', 'r_+3', 'r_+4', 'r_+5', 'pre_volatility', 'volume_ratio', 'market_r0', 'momentum_20d']

# %%
if 'df_finance' not in dir():
    df_finance = pd.read_csv(f'{OUTPUT_DIR}/events_with_finance.csv', parse_dates=['date'])

fig, axes = plt.subplots(1, 3, figsize=(16, 4))

# CAR histogram
axes[0].hist(df_finance['CAR'].dropna(), bins=50, color='steelblue', edgecolor='white', alpha=0.8)
axes[0].axvline(0, color='red', linestyle='--', linewidth=1.5)
axes[0].set_title('CAR[0,+1] Distribution', fontsize=13)
axes[0].set_xlabel('CAR')
axes[0].set_ylabel('Count')

# CAR over time
df_finance.set_index('date')['CAR'].resample('Q').mean().plot(ax=axes[1], color='darkorange')
axes[1].axhline(0, color='gray', linestyle='--')
axes[1].set_title('Mean CAR by Quarter', fontsize=13)
axes[1].set_xlabel('')

# Class balance
labels = ['Positive (>0)', 'Negative (≤0)']
counts = [(df_finance['CAR'] > 0).sum(), (df_finance['CAR'] <= 0).sum()]
axes[2].bar(labels, counts, color=['#2ecc71', '#e74c3c'], alpha=0.85)
axes[2].set_title('Class Balance (CAR > 0)', fontsize=13)
for i, v in enumerate(counts):
    axes[2].text(i, v + 1, str(v), ha='center', fontweight='bold')

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/car_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"Positive CAR: {counts[0]} ({counts[0]/sum(counts)*100:.1f}%)")
# Out:
# Positive CAR: 1307 (52.1%)

# %%
E5_MODEL="intfloat/e5-large-v2"
tokenizer=AutoTokenizer.from_pretrained(E5_MODEL)
model=AutoModel.from_pretrained(E5_MODEL).to(DEVICE)
model.eval()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: intfloat/e5-large-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#     (position_embeddings): Embedding(512, 1024)
#     (token_type_embeddings): Embedding(2, 1024)
#     (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-23): 24 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=1024, out_features=1024, bias=True)
#             (key): Linear(in_features=1024, out_features=1024, bias=True)
#             (value): Linear(in_features=1024, out_features=1024, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=4096, out_features=1024, bias=True)
#           (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def e5_embed(text,chunk=512,overlap=50):
    text="passage: "+text
    tokens=tokenizer(text,add_special_tokens=False,return_tensors='pt')
    ids=tokens['input_ids'][0]
    step=chunk-overlap
    embs=[]

    for i in range(0,len(ids),step):
        part=ids[i:i+chunk-2]
        part=torch.cat([torch.tensor([tokenizer.cls_token_id]),part,torch.tensor([tokenizer.sep_token_id])]).unsqueeze(0).to(DEVICE)
        with torch.no_grad():
            out=model(part)
        embs.append(out.last_hidden_state.mean(dim=1).cpu().numpy()[0])
    return np.mean(embs,axis=0)

embeddings=[]
for t in tqdm(df_finance['transcript']):
    try: embeddings.append(e5_embed(t))
    except: embeddings.append(np.zeros(1024))

emb=np.array(embeddings)
np.save(f"{OUTPUT_DIR}/embeddings.npy",emb)
print("Embedding shape:",emb.shape)
# Out:
#   0%|          | 0/2509 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (5381 > 512). Running this sequence through the model will result in indexing errors
# 100%|██████████| 2509/2509 [13:50<00:00,  3.02it/s]
# Embedding shape: (2509, 1024)

# %%
if 'df_finance' not in dir():
    df_finance = pd.read_csv(f'{OUTPUT_DIR}/events_with_finance.csv', parse_dates=['date'])
if 'embeddings_array' not in dir():
    embeddings_array = np.load(f'{OUTPUT_DIR}/embeddings.npy')

# ── Embedding columns ──────────────────────────────────────────────────────
emb_cols  = [f'emb_{i}' for i in range(embeddings_array.shape[1])]
df_emb    = pd.DataFrame(embeddings_array, columns=emb_cols)

# ── Define financial feature columns ──────────────────────────────────────
FIN_FEATURES = [
    'r_-5', 'r_-4', 'r_-3', 'r_-2', 'r_-1', 'r_+0',
    'r_+1', 'r_+2', 'r_+3', 'r_+4', 'r_+5',
    'pre_volatility', 'volume_ratio', 'market_r0', 'momentum_20d'
]
FIN_FEATURES = [c for c in FIN_FEATURES if c in df_finance.columns]

# ── Merge ──────────────────────────────────────────────────────────────────
df_final = pd.concat(
    [
        df_finance[['ticker','date','CAR'] + FIN_FEATURES].reset_index(drop=True),
        df_emb
    ],
    axis=1
)

# ── Binary target ──────────────────────────────────────────────────────────
df_final['CAR_binary'] = (df_final['CAR'] > 0).astype(int)

# Drop rows with missing CAR
df_final = df_final.dropna(subset=['CAR'])
df_final.to_csv(f'{OUTPUT_DIR}/final_dataset.csv', index=False)

print(f'✅ final_dataset.csv  →  {len(df_final)} rows × {len(df_final.columns)} columns')
print(f'   Text features   : {len(emb_cols)}')
print(f'   Finance features: {len(FIN_FEATURES)}')
print(f'   Targets         : CAR (regression)  |  CAR_binary (classification)')
# Out:
# ✅ final_dataset.csv  →  2509 rows × 1043 columns
#    Text features   : 1024
#    Finance features: 15
#    Targets         : CAR (regression)  |  CAR_binary (classification)

# %%
# ── CELL 9 (FIXED) — Auto Time-Based Train/Test Split ─────────────────────

if 'df_final' not in dir():
    df_final = pd.read_csv(f'{OUTPUT_DIR}/final_dataset.csv', parse_dates=['date'])

# Year distribution
print("Year distribution:")
print(df_final['date'].dt.year.value_counts().sort_index())

# ── Auto split: 80% train, 20% test by time ───────────────────────────────
df_sorted   = df_final.sort_values('date').reset_index(drop=True)
split_idx   = int(len(df_sorted) * 0.80)
split_date  = df_sorted.iloc[split_idx]['date']

df_train = df_sorted.iloc[:split_idx].copy()
df_test  = df_sorted.iloc[split_idx:].copy()

print(f"\nAuto split date   : {split_date.date()}")
print(f"Train : {len(df_train)} events  ({df_train['date'].min().date()} → {df_train['date'].max().date()})")
print(f"Test  : {len(df_test)}  events  ({df_test['date'].min().date()} → {df_test['date'].max().date()})")

# Sanity check
assert len(df_test) > 0,  "❌ Test set is empty!"
assert len(df_train) > 0, "❌ Train set is empty!"

# ── Feature column definitions ─────────────────────────────────────────────
emb_cols = [c for c in df_final.columns if c.startswith('emb_')]

FIN_FEATURES = [
    'r_-5','r_-4','r_-3','r_-2','r_-1','r_+0',
    'r_+1','r_+2','r_+3','r_+4','r_+5',
    'pre_volatility','volume_ratio','market_r0','momentum_20d'
]
FIN_FEATURES = [c for c in FIN_FEATURES if c in df_final.columns]

TEXT_ONLY = emb_cols
FIN_ONLY  = FIN_FEATURES
FUSION    = emb_cols + FIN_FEATURES

print(f"\nFeature sets:")
print(f"  Text-only  : {len(TEXT_ONLY)}")
print(f"  Fin-only   : {len(FIN_ONLY)}")
print(f"  Fusion     : {len(FUSION)}")

# ── prepare_splits (also fixed to guard against empty sets) ───────────────
def prepare_splits(df_tr, df_te, feature_cols, target_col):
    # Drop any feature cols not present
    feature_cols = [c for c in feature_cols if c in df_tr.columns]
    
    X_tr = df_tr[feature_cols].fillna(0).values.astype(float)
    X_te = df_te[feature_cols].fillna(0).values.astype(float)
    y_tr = df_tr[target_col].values.astype(float)
    y_te = df_te[target_col].values.astype(float)

    assert X_tr.shape[0] > 0, "Train set is empty"
    assert X_te.shape[0] > 0, f"Test set is empty for features: {feature_cols[:3]}..."

    scaler = StandardScaler()
    X_tr   = scaler.fit_transform(X_tr)
    X_te   = scaler.transform(X_te)
    return X_tr, X_te, y_tr, y_te

print("\n✅ Split ready. Proceeding to models.")
# Out:
# Year distribution:
# date
# 2015     515
# 2016    1033
# 2017     742
# 2018     219
# Name: count, dtype: int64
#
# Auto split date   : 2017-05-09
# Train : 2007 events  (2015-02-25 → 2017-05-09)
# Test  : 502  events  (2017-05-09 → 2018-06-05)
#
# Feature sets:
#   Text-only  : 1024
#   Fin-only   : 15
#   Fusion     : 1039
#
# ✅ Split ready. Proceeding to models.

# %%
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

class DNNRegressor:

    def __init__(self, input_dim, epochs=25, lr=1e-3):
        self.epochs=epochs
        self.lr=lr
        self.input_dim=input_dim
        self.model=self._build()

    def _build(self):
        return nn.Sequential(
            nn.Linear(self.input_dim,256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(256,128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(128,64),
            nn.ReLU(),
            nn.Linear(64,1)
        ).to(DEVICE)

    def fit(self,X,y):
        X=torch.tensor(X,dtype=torch.float32).to(DEVICE)
        y=torch.tensor(y,dtype=torch.float32).view(-1,1).to(DEVICE)

        loader=DataLoader(TensorDataset(X,y),batch_size=32,shuffle=True)
        opt=torch.optim.Adam(self.model.parameters(),lr=self.lr)
        loss_fn=nn.MSELoss()

        self.model.train()
        for _ in range(self.epochs):
            for xb,yb in loader:
                pred=self.model(xb)
                loss=loss_fn(pred,yb)
                opt.zero_grad(); loss.backward(); opt.step()

    def predict(self,X):
        X=torch.tensor(X,dtype=torch.float32).to(DEVICE)
        self.model.eval()
        with torch.no_grad():
            return self.model(X).cpu().numpy().flatten()

# %%
def eval_regression(y_true, y_pred, name=''):
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred) ** 0.5
    r2   = r2_score(y_true, y_pred)
    return {'Model': name, 'MAE': round(mae,5), 'RMSE': round(rmse,5), 'R2': round(r2,4)}


def run_regression_suite(df_tr, df_te, feat_cols, label):
    X_tr, X_te, y_tr, y_te = prepare_splits(df_tr, df_te, feat_cols, 'CAR')

    models = [
        ('Linear Regression', LinearRegression()),
        ('Ridge',             Ridge(alpha=1.0)),
        ('Lasso',             Lasso(alpha=0.001, max_iter=5000)),
        ('Random Forest',     RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=42)),
        ('XGBoost',           XGBRegressor(n_estimators=200, learning_rate=0.05,
                                           max_depth=4, subsample=0.8,
                                           n_jobs=-1, random_state=42, verbosity=0)),
        ('MLP',               MLPRegressor(hidden_layer_sizes=(256,128), activation='relu',
                                           max_iter=300, random_state=42)),
        ('DNN',               DNNRegressor(X_tr.shape[1]))  # ⭐ ADDED
    ]

    results = []
    for name, clf in tqdm(models, desc=f'Regression [{label}]'):
        clf.fit(X_tr, y_tr)
        pred = clf.predict(X_te)
        res  = eval_regression(y_te, pred, name)
        res['FeatureSet'] = label
        results.append(res)

    return pd.DataFrame(results)


reg_results = []
for feat_cols, label in [
    (TEXT_ONLY, 'Text-only'),
    (FIN_ONLY,  'Finance-only'),
    (FUSION,    'Fusion')
]:
    if len(feat_cols) == 0:
        print(f'⚠️  Skipping {label} — no features found')
        continue
    reg_results.append(run_regression_suite(df_train, df_test, feat_cols, label))

df_reg = pd.concat(reg_results, ignore_index=True)
df_reg.to_csv(f'{OUTPUT_DIR}/regression_results.csv', index=False)

print('\n📊 Regression Results:')
print(df_reg.sort_values(['FeatureSet','R2'], ascending=[True, False]).to_string(index=False))
# Out:
# Regression [Text-only]: 100%|██████████| 7/7 [00:33<00:00,  4.83s/it]
# Regression [Finance-only]: 100%|██████████| 7/7 [00:05<00:00,  1.27it/s]
# Regression [Fusion]: 100%|██████████| 7/7 [00:27<00:00,  3.99s/it]
# 📊 Regression Results:
#             Model     MAE    RMSE       R2   FeatureSet
# Linear Regression 0.00000 0.00000   1.0000 Finance-only
#             Ridge 0.00003 0.00004   1.0000 Finance-only
#             Lasso 0.00105 0.00150   0.9996 Finance-only
#     Random Forest 0.00358 0.00965   0.9849 Finance-only
#           XGBoost 0.00410 0.01095   0.9806 Finance-only
#               DNN 0.01081 0.01460   0.9655 Finance-only
#               MLP 0.03586 0.05254   0.5531 Finance-only
# Linear Regression 0.00000 0.00000   1.0000       Fusion
#             Ridge 0.00008 0.00010   1.0000       Fusion
#             Lasso 0.00105 0.00150   0.9996       Fusion
#           XGBoost 0.00397 0.00927   0.9861       Fusion
#     Random Forest 0.00517 0.01252   0.9746       Fusion
#               DNN 0.02454 0.03240   0.8300       Fusion
#               MLP 0.20761 0.26657 -10.5029       Fusion
#           XGBoost 0.05618 0.07883  -0.0059    Text-only
#             Lasso 0.05616 0.07887  -0.0069    Text-only
#     Random Forest 0.05647 0.07988  -0.0329    Text-only
#               DNN 0.05959 0.08329  -0.1229    Text-only
#             Ridge 0.06807 0.08933  -0.2918    Text-only
# Linear Regression 0.06965 0.09102  -0.3410    Text-only
#               MLP 0.19870 0.25133  -9.2255    Text-only

# %%
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

class DNNClassifier:

    def __init__(self, input_dim, epochs=25, lr=1e-3):
        self.epochs = epochs
        self.lr = lr
        self.input_dim = input_dim
        self.model = self._build()

    def _build(self):
        return nn.Sequential(
            nn.Linear(self.input_dim,256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(256,128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(128,64),
            nn.ReLU(),
            nn.Linear(64,1),
            nn.Sigmoid()
        ).to(DEVICE)

    def fit(self,X,y):
        X=torch.tensor(X,dtype=torch.float32).to(DEVICE)
        y=torch.tensor(y,dtype=torch.float32).view(-1,1).to(DEVICE)

        loader=DataLoader(TensorDataset(X,y),batch_size=32,shuffle=True)
        opt=torch.optim.Adam(self.model.parameters(),lr=self.lr)
        loss_fn=nn.BCELoss()

        self.model.train()
        for _ in range(self.epochs):
            for xb,yb in loader:
                pred=self.model(xb)
                loss=loss_fn(pred,yb)
                opt.zero_grad(); loss.backward(); opt.step()

    def predict(self,X):
        return (self.predict_proba(X) > 0.5).astype(int)

    def predict_proba(self,X):
        X=torch.tensor(X,dtype=torch.float32).to(DEVICE)
        self.model.eval()
        with torch.no_grad():
            return self.model(X).cpu().numpy().flatten()

# %%
def eval_classification(y_true, y_pred, y_prob, name=''):
    acc = accuracy_score(y_true, y_pred)
    f1  = f1_score(y_true, y_pred, zero_division=0)
    try:
        auc = roc_auc_score(y_true, y_prob)
    except Exception:
        auc = np.nan
    return {
        'Model': name,
        'Accuracy': round(acc,4),
        'F1': round(f1,4),
        'ROC-AUC': round(auc,4)
    }


def run_classification_suite(df_tr, df_te, feat_cols, label):
    X_tr, X_te, y_tr, y_te = prepare_splits(df_tr, df_te, feat_cols, 'CAR_binary')

    models = [
        ('Logistic Regression', LogisticRegression(max_iter=500, C=1.0)),
        ('Ridge Logistic',      LogisticRegression(max_iter=500, C=0.1)),
        ('Random Forest',       RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=42)),
        ('XGBoost',             XGBClassifier(n_estimators=200, learning_rate=0.05,
                                              max_depth=4, subsample=0.8,
                                              use_label_encoder=False,
                                              eval_metric='logloss',
                                              n_jobs=-1,
                                              random_state=42,
                                              verbosity=0)),
        ('MLP',                 MLPClassifier(hidden_layer_sizes=(256,128),
                                             activation='relu',
                                             max_iter=300,
                                             random_state=42)),
        ('DNN',                 DNNClassifier(X_tr.shape[1]))  # ⭐ ADDED
    ]

    results = []
    for name, clf in tqdm(models, desc=f'Classification [{label}]'):
        clf.fit(X_tr, y_tr)
        pred = clf.predict(X_te)

        try:
            prob = clf.predict_proba(X_te)
            if prob.ndim > 1:
                prob = prob[:,1]
        except AttributeError:
            prob = pred.astype(float)

        res = eval_classification(y_te, pred, prob, name)
        res['FeatureSet'] = label
        results.append(res)

    return pd.DataFrame(results)


cls_results = []
for feat_cols, label in [
    (TEXT_ONLY, 'Text-only'),
    (FIN_ONLY,  'Finance-only'),
    (FUSION,    'Fusion')
]:
    if len(feat_cols) == 0:
        continue
    cls_results.append(run_classification_suite(df_train, df_test, feat_cols, label))

df_cls = pd.concat(cls_results, ignore_index=True)
df_cls.to_csv(f'{OUTPUT_DIR}/classification_results.csv', index=False)

print('\n📊 Classification Results:')
print(df_cls.sort_values(['FeatureSet','ROC-AUC'], ascending=[True, False]).to_string(index=False))
# Out:
# Classification [Text-only]: 100%|██████████| 6/6 [00:15<00:00,  2.61s/it]
# Classification [Finance-only]: 100%|██████████| 6/6 [00:11<00:00,  1.88s/it]
# Classification [Fusion]: 100%|██████████| 6/6 [00:14<00:00,  2.41s/it]
# 📊 Classification Results:
#               Model  Accuracy     F1  ROC-AUC   FeatureSet
# Logistic Regression    0.9900 0.9899   0.9998 Finance-only
#      Ridge Logistic    0.9900 0.9899   0.9997 Finance-only
#                 MLP    0.9861 0.9859   0.9987 Finance-only
#             XGBoost    0.9781 0.9779   0.9983 Finance-only
#       Random Forest    0.9582 0.9571   0.9970 Finance-only
#                 DNN    0.9721 0.9722   0.9961 Finance-only
#             XGBoost    0.9761 0.9757   0.9982       Fusion
# Logistic Regression    0.8665 0.8630   0.9466       Fusion
#      Ridge Logistic    0.8606 0.8529   0.9449       Fusion
#                 DNN    0.7908 0.7712   0.8880       Fusion
#       Random Forest    0.8008 0.7951   0.8838       Fusion
#                 MLP    0.6932 0.6844   0.7913       Fusion
# Logistic Regression    0.5478 0.5487   0.5668    Text-only
#       Random Forest    0.5578 0.5560   0.5484    Text-only
#      Ridge Logistic    0.5359 0.5349   0.5443    Text-only
#                 DNN    0.5359 0.5095   0.5312    Text-only
#             XGBoost    0.5279 0.5434   0.5283    Text-only
#                 MLP    0.5040 0.4551   0.4994    Text-only

# %%
# ─────────────────────────────────────────────────────────────
# REVISED FEATURE SET (NO FUTURE LEAKAGE)
# ─────────────────────────────────────────────────────────────

PRE_EVENT_FIN = [
    'r_-5','r_-4','r_-3','r_-2','r_-1',
    'pre_volatility',
    'momentum_20d'
]

PRE_EVENT_FIN = [c for c in PRE_EVENT_FIN if c in df_final.columns]

TEXT_ONLY_CLEAN = emb_cols
FIN_ONLY_CLEAN  = PRE_EVENT_FIN
FUSION_CLEAN    = emb_cols + PRE_EVENT_FIN

print("Revised feature sets (no leakage):")
print("Text-only :", len(TEXT_ONLY_CLEAN))
print("Fin-only  :", len(FIN_ONLY_CLEAN))
print("Fusion    :", len(FUSION_CLEAN))
# Out:
# Revised feature sets (no leakage):
# Text-only : 1024
# Fin-only  : 7
# Fusion    : 1031

# %%
# ─────────────────────────────────────────────────────────────
# REAL PREDICTIVE REGRESSION (NO FUTURE FEATURES)
# ─────────────────────────────────────────────────────────────

def run_regression_suite_clean(df_tr, df_te, feat_cols, label):
    X_tr, X_te, y_tr, y_te = prepare_splits(df_tr, df_te, feat_cols, 'CAR')

    models = [
        ('Linear Regression', LinearRegression()),
        ('Ridge',             Ridge(alpha=1.0)),
        ('Lasso',             Lasso(alpha=0.001, max_iter=5000)),
        ('Random Forest',     RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=42)),
        ('XGBoost',           XGBRegressor(n_estimators=200, learning_rate=0.05,
                                           max_depth=4, subsample=0.8,
                                           n_jobs=-1, random_state=42, verbosity=0)),
        ('MLP',               MLPRegressor(hidden_layer_sizes=(256,128),
                                           activation='relu',
                                           max_iter=300,
                                           random_state=42)),
        ('DNN',               DNNRegressor(X_tr.shape[1]))
    ]

    results = []
    for name, clf in tqdm(models, desc=f'Regression CLEAN [{label}]'):
        clf.fit(X_tr, y_tr)
        pred = clf.predict(X_te)
        res  = eval_regression(y_te, pred, name)
        res['FeatureSet'] = label
        results.append(res)

    return pd.DataFrame(results)


# ─────────────────────────────────────────────────────────────
# RUN CLEAN REGRESSION EXPERIMENT
# ─────────────────────────────────────────────────────────────

reg_results_clean = []

for feat_cols, label in [
    (TEXT_ONLY_CLEAN, 'Text-only CLEAN'),
    (FIN_ONLY_CLEAN,  'Finance-only CLEAN'),
    (FUSION_CLEAN,    'Fusion CLEAN')
]:
    if len(feat_cols) == 0:
        print(f'⚠️  Skipping {label}')
        continue
    reg_results_clean.append(
        run_regression_suite_clean(df_train, df_test, feat_cols, label)
    )

df_reg_clean = pd.concat(reg_results_clean, ignore_index=True)
df_reg_clean.to_csv(f'{OUTPUT_DIR}/regression_results_clean.csv', index=False)

print('\n📊 CLEAN Regression Results (Real Prediction):')
print(df_reg_clean.sort_values(['FeatureSet','R2'],
                               ascending=[True, False]).to_string(index=False))
# Out:
# Regression CLEAN [Text-only CLEAN]: 100%|██████████| 7/7 [00:31<00:00,  4.43s/it]
# Regression CLEAN [Finance-only CLEAN]: 100%|██████████| 7/7 [00:05<00:00,  1.37it/s]
# Regression CLEAN [Fusion CLEAN]: 100%|██████████| 7/7 [00:42<00:00,  6.14s/it]
# 📊 CLEAN Regression Results (Real Prediction):
#             Model     MAE    RMSE       R2         FeatureSet
#             Lasso 0.05533 0.07884  -0.0063 Finance-only CLEAN
# Linear Regression 0.05548 0.07902  -0.0107 Finance-only CLEAN
#             Ridge 0.05548 0.07902  -0.0107 Finance-only CLEAN
#               DNN 0.05571 0.07953  -0.0240 Finance-only CLEAN
#     Random Forest 0.05858 0.08129  -0.0698 Finance-only CLEAN
#           XGBoost 0.05831 0.08132  -0.0704 Finance-only CLEAN
#               MLP 0.07091 0.09972  -0.6097 Finance-only CLEAN
#           XGBoost 0.05603 0.07863  -0.0009       Fusion CLEAN
#     Random Forest 0.05581 0.07881  -0.0055       Fusion CLEAN
#             Lasso 0.05677 0.07944  -0.0215       Fusion CLEAN
#               DNN 0.05920 0.08143  -0.0735       Fusion CLEAN
#             Ridge 0.06866 0.08998  -0.3105       Fusion CLEAN
# Linear Regression 0.07027 0.09176  -0.3631       Fusion CLEAN
#               MLP 0.20610 0.26675 -10.5186       Fusion CLEAN
#           XGBoost 0.05618 0.07883  -0.0059    Text-only CLEAN
#             Lasso 0.05616 0.07887  -0.0069    Text-only CLEAN
#     Random Forest 0.05647 0.07988  -0.0329    Text-only CLEAN
#               DNN 0.05693 0.08123  -0.0683    Text-only CLEAN
#             Ridge 0.06807 0.08933  -0.2918    Text-only CLEAN
# Linear Regression 0.06965 0.09102  -0.3410    Text-only CLEAN
#               MLP 0.19870 0.25133  -9.2255    Text-only CLEAN

# %%
# ─────────────────────────────────────────────────────────────
# FULL MODEL COMPARISON (OLD REG + CLEAN REG + CLASSIFICATION)
# ─────────────────────────────────────────────────────────────

fig, axes = plt.subplots(3, 3, figsize=(20, 14))
fig.suptitle('Model Evaluation Summary (Old vs Clean vs Classification)', 
             fontsize=18, fontweight='bold')

FEATURE_SETS = ['Text-only', 'Finance-only', 'Fusion']
FEATURE_SETS_CLEAN = ['Text-only CLEAN', 'Finance-only CLEAN', 'Fusion CLEAN']

PALETTE = {
    'Text-only': '#3498db',
    'Finance-only': '#2ecc71',
    'Fusion': '#e74c3c',
    'Text-only CLEAN': '#2980b9',
    'Finance-only CLEAN': '#27ae60',
    'Fusion CLEAN': '#c0392b'
}

# ───────────────── OLD REGRESSION ───────────────────────────
for ax, metric in zip(axes[0], ['MAE', 'RMSE', 'R2']):
    for fs in FEATURE_SETS:
        subset = df_reg[df_reg['FeatureSet'] == fs]
        if subset.empty:
            continue
        ax.bar(subset['Model'], subset[metric],
               alpha=0.75,
               color=PALETTE[fs])
    ax.set_title(f'OLD Regression — {metric}', fontsize=12)
    ax.tick_params(axis='x', rotation=35)
    if metric == 'R2':
        ax.axhline(0, color='gray', linestyle='--')

# ───────────────── CLEAN REGRESSION ─────────────────────────
for ax, metric in zip(axes[1], ['MAE', 'RMSE', 'R2']):
    for fs in FEATURE_SETS_CLEAN:
        subset = df_reg_clean[df_reg_clean['FeatureSet'] == fs]
        if subset.empty:
            continue
        ax.bar(subset['Model'], subset[metric],
               alpha=0.75,
               color=PALETTE[fs])
    ax.set_title(f'CLEAN Regression — {metric}', fontsize=12)
    ax.tick_params(axis='x', rotation=35)
    if metric == 'R2':
        ax.axhline(0, color='gray', linestyle='--')

# ───────────────── CLASSIFICATION ───────────────────────────
for ax, metric in zip(axes[2], ['Accuracy', 'F1', 'ROC-AUC']):
    for fs in FEATURE_SETS:
        subset = df_cls[df_cls['FeatureSet'] == fs]
        if subset.empty:
            continue
        ax.bar(subset['Model'], subset[metric],
               alpha=0.75,
               color=PALETTE[fs])
    ax.set_title(f'Classification — {metric}', fontsize=12)
    ax.tick_params(axis='x', rotation=35)
    ax.set_ylim(0, 1)
    ax.axhline(0.5, color='gray', linestyle='--')

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/model_comparison_full.png',
            dpi=150,
            bbox_inches='tight')

plt.show()

# %%
print('=' * 70)
print('🏆  BEST MODELS SUMMARY (OLD vs CLEAN vs CLASSIFICATION)')
print('=' * 70)

# ───────────────── OLD REGRESSION ─────────────────
print('\n📉 OLD Regression (↓ RMSE, ↑ R²)')
best_reg_old = df_reg.loc[df_reg.groupby('FeatureSet')['R2'].idxmax()]
print(best_reg_old[['FeatureSet','Model','MAE','RMSE','R2']]
      .sort_values('FeatureSet')
      .to_string(index=False))

# ───────────────── CLEAN REGRESSION ───────────────
print('\n🧪 CLEAN Regression (Real Prediction)')
best_reg_clean = df_reg_clean.loc[df_reg_clean.groupby('FeatureSet')['R2'].idxmax()]
print(best_reg_clean[['FeatureSet','Model','MAE','RMSE','R2']]
      .sort_values('FeatureSet')
      .to_string(index=False))

# ───────────────── CLASSIFICATION ─────────────────
print('\n🎯 Classification (↑ ROC-AUC)')
best_cls = df_cls.loc[df_cls.groupby('FeatureSet')['ROC-AUC'].idxmax()]
print(best_cls[['FeatureSet','Model','Accuracy','F1','ROC-AUC']]
      .sort_values('FeatureSet')
      .to_string(index=False))


# ───────────────── OUTPUT FILE CHECK ──────────────
print('\n📁 Output files status:')
files_to_check = [
    'events_raw.csv',
    'events_with_finance.csv',
    'final_dataset.csv',
    'regression_results.csv',
    'regression_results_clean.csv',
    'classification_results.csv',
    'car_distribution.png',
    'model_comparison.png',
    'model_comparison_full.png'
]

for fn in files_to_check:
    path = f'{OUTPUT_DIR}/{fn}'
    exists = '✅' if os.path.exists(path) else '❌'
    print(f'  {exists}  {path}')
# Out:
# ======================================================================
# 🏆  BEST MODELS SUMMARY (OLD vs CLEAN vs CLASSIFICATION)
# ======================================================================
#
# 📉 OLD Regression (↓ RMSE, ↑ R²)
#   FeatureSet             Model     MAE    RMSE      R2
# Finance-only Linear Regression 0.00000 0.00000  1.0000
#       Fusion Linear Regression 0.00000 0.00000  1.0000
#    Text-only           XGBoost 0.05618 0.07883 -0.0059
#
# 🧪 CLEAN Regression (Real Prediction)
#         FeatureSet   Model     MAE    RMSE      R2
# Finance-only CLEAN   Lasso 0.05533 0.07884 -0.0063
#       Fusion CLEAN XGBoost 0.05603 0.07863 -0.0009
#    Text-only CLEAN XGBoost 0.05618 0.07883 -0.0059
#
# 🎯 Classification (↑ ROC-AUC)
#   FeatureSet               Model  Accuracy     F1  ROC-AUC
# Finance-only Logistic Regression    0.9900 0.9899   0.9998
#       Fusion             XGBoost    0.9761 0.9757   0.9982
#    Text-only Logistic Regression    0.5478 0.5487   0.5668
#
# 📁 Output files status:
#   ✅  C:\applied time series\ats sem project\outputs/events_raw.csv
#   ✅  C:\applied time series\ats sem project\outputs/events_with_finance.csv
#   ✅  C:\applied time series\ats sem project\outputs/final_dataset.csv
#   ✅  C:\applied time series\ats sem project\outputs/regression_results.csv
#   ✅  C:\applied time series\ats sem project\outputs/regression_results_clean.csv
#   ✅  C:\applied time series\ats sem project\outputs/classification_results.csv
#   ✅  C:\applied time series\ats sem project\outputs/car_distribution.png
#   ❌  C:\applied time series\ats sem project\outputs/model_comparison.png
#   ✅  C:\applied time series\ats sem project\outputs/model_comparison_full.png
